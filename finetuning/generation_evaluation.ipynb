# %% [markdown]
# # Tutorial: A Closer Look into the Humorous Caption Generation with Pretrained/Finetuned Models

# %% [markdown]
# ## Setup
#
# All our pretrained/finetuned models use the huggingface API, you will need to first enter your huggingface login token.

# %%
from huggingface_hub import login    
login(token="your_huggingface_token")

# %% [markdown]
# You can refer to the `README.md` file to finetune the model and generate captions on your own. For the rest of this tutorial, we will use the captions that we have generated already on the test split.

# %% [markdown]
# ## A Closer Look into the Sample Generation

# %%
import pandas as pd
from diversity import compute_cosine_SBERT, compute_averageEAD
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We use the cosine similarity, `compute_cosine_SBERT`, on the sentence bert embedding (`all-mpnet-base-v2`), and the expectation-adjusted distinct N-grams (EAD), `compute_averageEAD` to evaluate the diversity of the generated captions.

# %% [markdown]
# ### Captions from Human Contestants

# %%
df = pd.read_csv('../examples/generations/human_top.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.745247483253479
# Averaged EAD:  0.9455847415190286
#                                                     0  \
# 0   I really just thought they would send me a lap...
# 1   Given Mr Tell's declining accuracy with his bo...
# 2   Well, five acres of popcorn back there says yo...
# 3                       I'd like to see other people.
# 4   Our timeshare presentation will begin in about...
# ..                                                ...
# 86                 I forgot what I came upstairs for.
# 87       I would prefer to go out the way we came in.
# 88  It’s good to be back in the field. It just was...
# 89  Whoa, the new recruit went down the laundry ch...
# 90  I thought partly cloudy with a chance of rage ...
#
#                                                     1  \
# 0                        If he farts I'm out of here.
# 1   Where exactly is Bethlehem, NY? Hmmm. Off the ...
# 2   So Major Tom... Do you know how fast you were ...
# 3   I know that look, you're not going to let this...
# 4         If you get a choice the East River is nice.
# ..                                                ...
# 86                 Those better not be my good rocks.
# 87                   I usually wake up at this point.
# 88  Every time they say 'baa'  please stop saying ...
# 89  I have a feeling there’s a psychologist waitin...
# 90  Well it looks like my mother found out that yo...
#
#                                                     2  \
# 0     Well, at least the 800-lb gorilla finally left.
# 1   I liked it better when they were just little v...
# 2   Sir, I don't make the laws of physics I just e...
# 3                       I'd like to see other people.
# 4   Grammatically, indeed it IS sleep with the fis...
# ..                                                ...
# 86      On second thought, put them back in a circle.
# 87            Talk about being consumed by your work.
# 88  Remember to check for faces—I once barked at a...
# 89                      After you - I’m out of shape.
# 90  They banned him from Twitter, but he’s still i...
#
#                                                     3  \
# 0                 I see it. Don't change the subject.
# 1   I liked it better when the voices were inside ...
# 2   I'm going to need you to take one small step o...
# 3   What a delightful coincidence. I'm also recent...
# 4   So Vito tells me you're leaving the organization.
# ..                                                ...
# 86  How about you do a little more hunting and a l...
# 87                     I guess its just us for dinner
# 88  Remember Dave, Rule #1: Never Count Them. Dave...
# 89  Wait, is the call for Times Square or Columbus...
# 90               That reminds me. Your mother called.
#
#                                                     4  \
# 0       We're seeing the end of the Republican party.
# 1   It wouldn't be so bad if their printers weren'...
# 2   I don't make the laws of physics, sir. I just ...
# 3               Maybe his second week will go better.
# 4                   How was your flight in on United?
# ..                                                ...
# 86      For God’s sake George, put on some underwear.
# 87    Not the return to inside dining I was expecting
# 88      Ewe, ewe. ewe. That's all we ever talk about.
# 89  I’m not sure the department knows what diversi...
# 90               A bunny. Seriously. You see a bunny.
#
#                                                     5  \
# 0             The zoo won't pay the ransom. Now what?
# 1                 Are you thinking what I'm thinking?
# 2   Sir, please take one small step out of the veh...
# 3   The corrupt media will blow this way out of pr...
# 4        Bob tells me you're reconsidering our offer.
# ..                                                ...
# 86          I can't remember what I came up here for.
# 87  It's slow now, but we'll be pooped by the end ...
# 88  This is nothing.  Herding cats -- that's a rea...
# 89              What if I don't identify with either?
# 90  What do I think? I think we should stop asking...
#
#                                                     6  \
# 0   Face it: 'Ms. Bigly' refuses to go with you to...
# 1                 Have your person contact my person.
# 2        Take one small step out of the vehicle, sir.
# 3              I want to start seeing other people...
# 4              So when are you two taking the plunge?
# ..                                                ...
# 86          Well, just look at you, Mr. Homo Erectus.
# 87       I hear that the dinner crowd comes in waves.
# 88  They refuse to budge. They claim they have her...
# 89        I guess it depends on what shape you’re in.
# 90  He was banned from Facebook and Twitter, so he...
#
#                                                     7  \
# 0                           It looked smaller online.
# 1    I live in constant fear he will hit ctrl+alt+del
# 2   You call it a glitch in the space-time continu...
# 3   Hopefully the president's second day in office...
# 4   Well, we did tell you it was your going away p...
# ..                                                ...
# 86  Marry a hunter or gatherer," they said. "But h...
# 87           I thought you said the job was in Wales!
# 88  Herding is okay, but what I’d really like to d...
# 89           I see the diversity committee met again.
# 90        What the hell did you upload to the cloud?!
#
#                                                     8  \
# 0   Why can't you just wear a button, like most pe...
# 1   Don't you miss the days when we thought about ...
# 2              I got you doing light in a sound zone.
# 3                                    Oh, and I'm gay.
# 4   I'm taking the bridge home--I'd be happy to dr...
# ..                                                ...
# 86  First a "wheel" attached to nothing. Now "stai...
# 87  Study for six years in Paris and you're stuck ...
# 88  I have to admit, I’ve been sleeping a lot bett...
# 89  Since when did the pizza delivery guy get his ...
# 90  The forecast did say the weather would turn ugly.
#
#                                                     9
# 0                    Well SOMEONE clogged the toilet.
# 1                          Have your guy call my guy.
# 2   If you stay below the speed of sound you'll he...
# 3     I wonder what Donald will do on his second day?
# 4   when you said you were tied up, I assumed you ...
# ..                                                ...
# 86       Is this another one of your pyramid schemes?
# 87  hate to say it, but there's a way out in the back
# 88           One is missing?  What does it look like?
# 89                     I guess this makes us bi-polar
# 90          He hates when someone steals his thunder.
#
# [91 rows x 10 columns]

# %%
df = pd.read_csv('../examples/generations/human_200.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.7495863735675812
# Averaged EAD:  0.9564068457237652
#                                                     0  \
# 0   This is the last time we pet sit for the Ringl...
# 1   I still think a simple light bulb gets the ide...
# 2                         Your tail light is on fire.
# 3                                      Adam. And you?
# 4                     I see I have a captive audience
# ..                                                ...
# 86                       I'm too stoned to come down.
# 87           Now I understand why it’s called Jonah’s
# 88                        It sure beats herding cats.
# 89  Where's the triangle? I practiced with a TRIAN...
# 90  Remember when I told you my ex-wife has powerf...
#
#                                                     1  \
# 0   I miss the days when the political parties jus...
# 1   I'll have my guy email your guy, and we'll do ...
# 2                 January 23rd, 2017. Why do you ask?
# 3          So, now that I AM the last man on Earth...
# 4   At this point, does it really matter, red or w...
# ..                                                ...
# 86                     Can you see Russia from there?
# 87  kinda gives catch of the day a\ndifferent pers...
# 88  Are you closing your eyes or did you finish co...
# 89                the right one is for pizza delivery
# 90       He’s been under a lot of low pressure lately
#
#                                                     2  \
# 0            No more house-sitting for the Ringlings.
# 1                 Are you thinking what I'm thinking?
# 2   Oh yeah? Well around here, we like the sound b...
# 3         In real estate we call this an opportunity.
# 4                   Of course you'll stay for dinner?
# ..                                                ...
# 86  I call it a walk-up. My next idea is the brown...
# 87  At a time like this, we must ask the question:...
# 88              Watch what happens when I yell MOTHS!
# 89  Remind me again why we hired a Bauhaus architect?
# 90  The forecast calls for vengeance, with a chanc...
#
#                                                     3  \
# 0           Don't worry. He'll be gone by November 9.
# 1         Have you always supported small businesses?
# 2         Yeah, you can't always rely on Google maps.
# 3   But 'Kim Jong Eun is a stinkyface' was a prett...
# 4         I've noticed you two haven't been mingling.
# ..                                                ...
# 86  Did you seriously get me a Stair Master for my...
# 87  I guess we should have been more specific abou...
# 88       WAKE UP !! I told you to never count them!!"
# 89                  No no, that one is for the pizza!
# 90  Well he has been under a lot of Barometric Pre...
#
#                                                     4  \
# 0              I almost prefer the 800-pound gorilla.
# 1                 Are you thinking what I'm thinking?
# 2   Given everything else, I’m gonna overlook the ...
# 3   OK, so I voted wrong -- you act like it's the ...
# 4   So where do you two see yourselves in the next...
# ..                                                ...
# 86    Stairs are okay....but have you seen the wheel?
# 87     Some guy named Jonah is joining us for dinner.
# 88                            We're named after them.
# 89  It’s freedom of choice, but the destination is...
# 90  They must have gotten blown over from a red st...
#
#                                                     5  \
# 0   I don't complain about the donkey in the kitch...
# 1   Remember the old days when I had Georgia on my...
# 2   You realize that was a rolling stop back there...
# 3   So just to clarify, that was NOT even if I was...
# 4   Sorry. The magician we hired had to leave sudd...
# ..                                                ...
# 86  You’ll do anything to avoid hunting and gather...
# 87   Last time you pick the spot for a pop-up, Jonah.
# 88  I don’t see why it’s so hard to round up all t...
# 89         Is this part of our new diversity program?
# 90  I can handle threatening clouds. What I can’t ...
#
#                                                     6  \
# 0            Let's donate to the Democrats next time.
# 1   I loved the Apple iwatch and Google Glass, but...
# 2                    Ground control to major dumbass.
# 3   Don't care what the neighbors might say, I sti...
# 4      No, I can't say I have ever slept with a fish.
# ..                                                ...
# 86              Do you think this is the right angle?
# 87  We may have taken the 'farm to table' dining c...
# 88  I enjoy being around animals that smell worse ...
# 89                                      Where's Peg?"
# 90  It's cloud illusions I recall. I really don't ...
#
#                                                     7  \
# 0   I told him it was ok to hide out here until af...
# 1           Shh... They can hear what we're thinking!
# 2                  You failed to yield upon re-entry.
# 3   Sure, maybe it was Russia. Maybe it was China....
# 4   Darlings, I absolutely didn't expect you. The ...
# ..                                                ...
# 86            You’re a hoarder Mike. There I said it.
# 87        On this week’s episode of Hell’s Kitchen...
# 88  The challenge you see, is doing the job withou...
# 89  I just think to be politically correct we shou...
# 90  "I didn't think you were referring to umbrella...
#
#                                                     8  \
# 0                       Was that YOU or the elephant?
# 1   Have your people call my people, and we'll do ...
# 2   Then out of nowhere, officer, some total aster...
# 3   Your exact words were, "Maybe if you were the ...
# 4   Our host thought you might be interested in he...
# ..                                                ...
# 86            Yes, it's Pythagoras, how did you know?
# 87  In hindsight, we should’ve gone with the vegan...
# 88  Watch out! If that one escapes we lose herd im...
# 89                         Oh no - we've gone metric!
# 90                            ‘He’s ready to rumble.’
#
#                                                     9
# 0                   He looked so much smaller on Ebay
# 1   What do you THINK?" "I don't know - how do you...
# 2   You need to practice a little more ground cont...
# 3   Apparently, our neighborhood was ruining the v...
# 4   So what part of "surprise party" don't you und...
# ..                                                ...
# 86           Invest in the first ever pyramid scheme!
# 87          Call you Ishmael?\nCall me bouillabaisse!
# 88                         Are you sure they're mine?
# 89                     I think we're being polerized.
# 90     I wouldn’t hold your breath for silver lining.
#
# [91 rows x 10 columns]

# %%
df = pd.read_csv('../examples/generations/human_1000.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.7522215098142624
# Averaged EAD:  0.9608193014367068
#                                                     0  \
# 0                               Do you smell peanuts?
# 1   You find that you're taking your work home wit...
# 2   Sorry, but I'm not buying the 'broken speedome...
# 3                       I guess the honeymoon's over.
# 4   It's an off-vintage for Bordeaux. Trust me, yo...
# ..                                                ...
# 86         Can you stop stonewalling for two seconds?
# 87                  I can't work in a dive like this.
# 88  How long do you think it will be til the press...
# 89  Another new guy went down the mail chute! I gu...
# 90          It started with Bob Dylan going electric.
#
#                                                     1  \
# 0           He's hiding out until after the election.
# 1             Work was on my mind before it was cool.
# 2   The bad news is you're under arrest. The good ...
# 3   You forgot to change the nuclear codes, didn't...
# 4   Our administration's hazing is a friendlier fo...
# ..                                                ...
# 86  Yes, I am impressed. Unfortunately, we just en...
# 87                               He must be starving.
# 88  You're right, Fido! It DOES look as if someone...
# 89                  Well, this isn't fair and square.
# 90             Looks like we're in for nasty weather.
#
#                                                     2  \
# 0                      This may be the end of the GOP
# 1                     Overhead's a real problem here.
# 2                    Well, at least you're not drunk.
# 3                    Adam and Eve:The Next Generation
# 4              Charles tells me you swim with fishes.
# ..                                                ...
# 86  Well that proves it...you can tell them all th...
# 87  Ok, what's the kitchen hack for this one, Jonah?"
# 88  How many did we start out with anyway?  Bud? H...
# 89      Round for fire calls.  Square for Zoom calls.
# 90  We won't get wet. Those are rage clouds, not r...
#
#                                                     3  \
# 0                                  Do metaphors poop?
# 1                    It's desk work all the way down.
# 2   I'll let you go this time, but just because yo...
# 3                           Well, we made it to 2017.
# 4     Does this mean you two are back together again?
# ..                                                ...
# 86  I don’t know... I’m still hung up on that spir...
# 87          A tough gig for a couple of pastry chefs.
# 88     How many times must I tell you, no ewe turns!?
# 89                 I'm just going to take the stairs.
# 90                    Oh, so for once you see it too?
#
#                                                     4  \
# 0   Wouldn't a "Make America Great Again" cap have...
# 1   Ever have that dream where you're driving home...
# 2             We're going to need a bigger tow truck.
# 3          But the point is, we voted our conscience.
# 4   Well hello, I'd heard you two weren't free ton...
# ..                                                ...
# 86  Last chance, Ethel. If I get on this mammoth, ...
# 87               You did name the restaurant Ishmael.
# 88  Herd immunity” does not mean what you think it...
# 89  That its square doesn't bother me...what bothe...
# 90                  This is definitely not cloud nine
#
#                                                     5  \
# 0   I miss understood it when you said that having...
# 1   Do you think he would have drawn apples if his...
# 2         License and alien registration card please.
# 3                                       You get half.
# 4                        Let's just say you're toast!
# ..                                                ...
# 86                              Are you being obtuse?
# 87                I have an idea for today’s special.
# 88      Stay sharp.  They're considering outsourcing.
# 89                                          Call 911.
# 90                          Blue skies frowning at me
#
#                                                     6  \
# 0   I know it's between this thing and Hillary, I'...
# 1            It's like we're in a New Yorker cartoon.
# 2     No, you're about 2,000 miles east of Bonneville
# 3                    But what about Hillary's emails?
# 4       I'm guessing this wasn't on your bucket list.
# ..                                                ...
# 86  First the wheel, now this ... I will be so hap...
# 87  They weren't lying when they said it takes gut...
# 88         Mary really pulled the wool over your eyes
# 89           I dunno. The options are awfully binary.
# 90  He's been following me around because I'm not ...
#
#                                                     7  \
# 0             Thanks for making our house great again
# 1           I think miniaturization has gone too far.
# 2   Do you know how fast you were going? I would l...
# 3   Frankly, I liked it better before they drained...
# 4   That's the only way I would be able to stop dr...
# ..                                                ...
# 86                                  Tomb with a view?
# 87  Not even Julia could get a soufflé out in this...
# 88   Remember, don't count them while you're on watch
# 89                       Which one is for introverts?
# 90                 Don't worry, he's full of hot air.
#
#                                                     8  \
# 0               I wish you'd just gotten a yard sign!
# 1    Flat tops would have been better than desk tops.
# 2                                           Seatbelt?
# 3   I think we need to take a harder look at the E...
# 4   So I'm guessing you didn't got the memo on dis...
# ..                                                ...
# 86                            I call it Times Square.
# 87      I think you might need a bigger boning knife.
# 88  Boss is on a tear. Ewe lose one and the sheep ...
# 89  So, I asked my high school math teacher, "When...
# 90  So, here's a fun fact ... not every cloud has ...
#
#                                                     9
# 0   No one ever asks if there is ROOM for the elep...
# 1   It's clearer now but I miss the Angel and the ...
# 2               No, I can't forget it just this once.
# 3   I guess it's now up to us to make America grea...
# 4                   So why were you two running late?
# ..                                                ...
# 86  No more hunter-gatherer. It's upper management...
# 87                          What would Bobby Flay do?
# 88       Ever notice how you begin to look like them?
# 89  It's part of the Department's new Diversity Se...
# 90  Is this what they mean when they say "the gods...
#
# [91 rows x 10 columns]

# %%
df = pd.read_csv('../examples/generations/human_median.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.7489385604858398
# Averaged EAD:  0.959699228394541
#                                                     0  \
# 0            I thought it'd be more of a greeny grey.
# 1                        Mine has more GB than yours.
# 2                               I can see your point.
# 3             So, what did you think of the election?
# 4   I hear you, sister. We want them to be abstrac...
# ..                                                ...
# 86  Yes, it's a perfect height for the Widow's Wal...
# 87          Unless he has heartburn, we have no heat.
# 88              Counting them is putting me to sleep.
# 89  I don't mind the geometric building. The real ...
# 90            There's a 30 percent chance he's angry.
#
#                                                     1  \
# 0                                                Sex.
# 1                  When does yours usually clock out?
# 2   'Sorry, Officer. I missed the turnoff for the ...
# 3                My name is Adam; may I call you Eve?
# 4             We only need to be watered once a week.
# ..                                                ...
# 86  I would have built a more conventional cairn, ...
# 87  As an outsider it is always easier to make dec...
# 88       Are we really tall or are they really short?
# 89  Let's handle this choice with 'Rock, Paper, Sc...
# 90  Do you think we are not socially distanced eno...
#
#                                                     2  \
# 0           Umm, no, we can't just agree to disagree!
# 1   I hate it when my boss is standing over me. Wh...
# 2   Again, Mr. Yeager, you’ve really gotta keep it...
# 3             My 401k has taken a real hit this year.
# 4   I'd offer you a drink but it looks like you're...
# ..                                                ...
# 86                              Nothing yet , Moses ?
# 87  Instead of spare ribs for tonight, I'm thinkin...
# 88   Sometimes I feel like a dog in sheep's clothing.
# 89  It's a good start for polygon inclusion, but I...
# 90  Is it because you don’t like small talk?”\n“No...
#
#                                                     3  \
# 0   Well, at least we know what the elephant in th...
# 1                I'm Atlas. What's your name, fucker?
# 2   I clocked you doing Mach 1. Minimum speed here...
# 3     This is why no one comes to Syria for vacation!
# 4        "You wanted the drinks 'straight up', right?
# ..                                                ...
# 86                       It's all downhill from here.
# 87    The recipe was posted by someone named "Jonah".
# 88  Bend down, tease your hair and we will fit rig...
# 89            The laundry chute will never be missed.
# 90          Looks like it's gonna rain rats and hogs.
#
#                                                     4  \
# 0                           I am not talking about it
# 1                OK, now clear your mind and relax...
# 2   I stopped you because both your tail lights ar...
# 3                     It's your fault for not voting.
# 4                                I just love your tie
# ..                                                ...
# 86                 Baby,let me take you too the moon!
# 87  She said she's through with always being on th...
# 88  Tom, you do umderstand we are not paid too ent...
# 89                       What? No transgender option.
# 90             I think it’s called ‘cumulus angryus’”
#
#                                                     5  \
# 0   Let's face it, Harry. The Republican Party is ...
# 1                             GET A LIFE OF YOUR OWN!
# 2   How fast do you think you were going? And don'...
# 3   Do you agree I was right about the results of ...
# 4   This is your last chance: fleshy with nutmeg e...
# ..                                                ...
# 86  This is it Rose! Are you coming or staying wit...
# 87             I said funnel cake , not tunnel cake !
# 88  I prefer goat yoga. It doesn’t feel like this ...
# 89       I guess inclusion has come to the firehouse.
# 90      Remember that time when Al Gore won an Oscar?
#
#                                                     6  \
# 0               I liked the 800-pound gorilla better.
# 1   Correct, you're the personification of youth's...
# 2                 Yah. Sure, pal. And I'm an UberCOP.
# 3   This might sound like a stupid question but di...
# 4   I'm a friend of Luca's. Do you swim with the f...
# ..                                                ...
# 86  Daniel, say you will take me out to dinner now...
# 87                            Sure is lonely in here.
# 88                  Having family is such a blessing!
# 89  Great. I had two extra donuts. Go get the jaws...
# 90          Cloud confrontation swollen up and fed up
#
#                                                     7  \
# 0   Perhaps its time we talk about the 800 lb gori...
# 1            This job is really getting on top of me.
# 2                      Have the need for speed do we?
# 3               But he has almost completed the wall.
# 4                Your just bound to meet people here.
# ..                                                ...
# 86  Dont make me come up there again, you know wha...
# 87                                    Tur-duck-hum-an
# 88                                      I miss Ralph.
# 89   Does this mean I have to use different pronouns?
# 90  Reading ‘The Cloud of Unknowing’ during the pa...
#
#                                                     8  \
# 0   Yes, dear. I'll put the skeletons back in the ...
# 1        Two parallel processors are better than one.
# 2   Texting while operating a vehicle is illegal i...
# 3                    'Well, that was unconventional."
# 4   So Canada said no to your immigration applicat...
# ..                                                ...
# 86   I call it ‘the wheel’ - it’s just an early draft
# 87  Sure the menu is always fish but at least we d...
# 88  A fox I know thinks this job would be perfect ...
# 89                  This new decorator has got to go.
# 90  I know it looks ominous, but they said the pan...
#
#                                                     9
# 0   Of course he's a cliche, but I still want to t...
# 1                       I wish he'd roll off my head.
# 2         I'm curious - is this the new hybrid model?
# 3   Shall we NOT go to the coffee shop, or NOT go ...
# 4   Now, that's what I call a pre-existing condition!
# ..                                                ...
# 86  Isn't there supposed to be a flagpole at the e...
# 87  I’m sorry. I forgot it. Ok? We’re just gonna h...
# 88  I’m just saying we have more in common with th...
# 89                            Well, if the hole fits!
# 90  Do you think he’s mad because we’re blocking t...
#
# [91 rows x 10 columns]

# %% [markdown]
# ### Captions from Private LLM

# %%
df = pd.read_csv('../examples/generations/claude.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.6812593936920166
# Averaged EAD:  0.9533062207625934
#                                                     0  \
# 0   I know I've put on a few pounds, but really, d...
# 1   I heard the other department is staffed entire...
# 2      Sir, I clocked you going Mach 3 in a 55 zone."
# 3   I know the neighborhood has gone downhill, but...
# 4   I thought they said this was a wine and chain ...
# ..                                                ...
# 86    The latest in Neolithic home security systems."
# 87  I told you we should have taken that left turn...
# 88  I told you we should've gone with the miniatur...
# 89  I told the architect I wanted to think outside...
# 90  I swear, if that cloud yells at me one more ti...
#
#                                                     1  \
# 0           I was told this was a 'jumbo' sized room.
# 1   So this is what they mean by putting our heads...
# 2                           Learner's permit, please.
# 3   I told you we should have turned left at the l...
# 4   So this is what they mean by being a 'captive ...
# ..                                                ...
# 86  When you said 'rock concert,' this wasn't what...
# 87  So this is what they mean by 'farm to table'."...
# 88        I think we're going to need a bigger fence.
# 89  Frank never quite fit in with the rest of the ...
# 90  Honey, I think the weather forecast was a bit ...
#
#                                                     2  \
# 0   Martha, I thought you said you were getting a ...
# 1   I guess open office plans have really gone to ...
# 2                            Elon, is that you again?
# 3         Perfect spot for a quiet, romantic getaway.
# 4   I appreciate the vintage, but the bondage is a...
# ..                                                ...
# 86  Early attempts at rock climbing were a bit... ...
# 87  I guess we're the ones being served today." Th...
# 88  Well, at least we won't have to worry about an...
# 89  When you try to cut corners in the fire statio...
# 90      Well, there goes our perfect day at the park.
#
#                                                     3  \
# 0    I guess we can cancel that pest control service.
# 1        Brings new meaning to the term 'headcount.'"
# 2   Just keep driving straight until you reach the...
# 3         The brochure did say 'ruins with a view'...
# 4   Apparently 'BYOB' meant 'Bring Your Own Bondage'.
# ..                                                ...
# 86         The world's first modern art installation.
# 87  Next time, let's stick to the kitchen." The ch...
# 88  Honey, did you accidentally order the sheep do...
# 89  The 90-degree pole For firefighters who prefer...
# 90  I told you we shouldn't have had that picnic i...
#
#                                                     4  \
# 0                  Next time, I'm picking the Airbnb.
# 1      I hope they offer good mental health benefits.
# 2   No, sir, 'to the moon' is not an acceptable de...
# 3                  Next time, I pick the picnic spot.
# 4   I came for the Merlot, but I'm staying against...
# ..                                                ...
# 86         Introducing the all-new Stonehenge Mini™!"
# 87           I knew we shouldn't have trusted that fi
# 88  I knew we shouldn't have let them near the mir...
# 89  Looks like somebody didn't get the memo about ...
# 90  I guess Mother Nature woke up on the wrong sid...
#
#                                                     5  \
# 0                  Well, there goes the neighborhood.
# 1                 Talk about a brainstorming session.
# 2   Next time, please use the designated spacecraf...
# 3                    Fallout Shelter for two, please.
# 4   This gives a whole new meaning to being 'tied ...
# ..                                                ...
# 86      The caveman's version of 'Netflix and chill.'
# 87  Well, at least we won't run out of salt." The ...
# 88  Something tells me they're eating more than ju...
# 89       You know Tim, he always has to be different.
# 90   Looks like somebody's got a case of the Mondays.
#
#                                                     6  \
# 0   I knew we should have measured the doorways fi...
# 1   I knew they wanted us to be more head-strong, ...
# 2   I'm going to need to see your intergalactic dr...
# 3           Urban renewal project phase one complete.
# 4   I guess we're a 'a chain gang' instead of 'a w...
# ..                                                ...
# 86              When you forget how to play Jenga..."
# 87  I hope this counts as hazard pay." The chefs a...
# 88   Good luck telling them to get off the furniture.
# 89                         Equality for all polygons!
# 90  I knew we shouldn't have trusted a weather app...
#
#                                                     7  \
# 0        Anybody know how to potty train an elephant?
# 1   Looks like management finally got their wish o...
# 2   This isn't the kind of high I usually deal wit...
# 3   I don't know, this minimalist architecture is ...
# 4   Usually the wine has a full body, not the guests!
# ..                                                ...
# 86               The prehistoric version of 'I Spy.'"
# 87  Note to self update resume." After this experi...
# 88  Time to update the 'Employees Must Wash Paws' ...
# 89  The poles may vary in shape, but our commitmen...
# 90  Guess the cloud didn't get the memo about 'tur...
#
#                                                     8  \
# 0   Looks like Junior is going through a gray period.
# 1   I guess this is one way to ensure we're always...
# 2                       Well, you can't park it here.
# 3   The realtor swore this was an up-and-coming ne...
# 4   'Wine flight' doesn't mean what I thought it d...
# ..                                                ...
# 86  Proof that procrastination has been around sin...
# 87  This gives a whole new meaning to 'belly of th...
# 88           And yet, still easier than herding cats.
# 89  I thought they said this station was 'hole-ist...
# 90  Maybe we need to organize a group therapy sess...
#
#                                                     9  contest_num
# 0   "Honey, I think it followed you home from the ...        543.0
# 1   "I heard the boss is a real stickler for face ...        544.0
# 2   "NASA budget cuts are really getting out of hand.        548.0
# 3                "Ah, just like the day we first met.        553.0
# 4          "This Chardonnay pairs well with shackles.        568.0
# ..                                                ...          ...
# 86     "The earliest known attempt at a rock garden."        746.0
# 87  "And they said culinary school was a waste of ...        748.0
# 88        "I knew we should have gone with a Lab mix.        750.0
# 89  "We had to make some compromises to get the st...        754.0
# 90  "I always thought 'Old Man Yells at Cloud' wou...        757.0
#
# [91 rows x 11 columns]

# %%
df = pd.read_csv('../examples/generations/gpt4o.csv')
compute_cosine_SBERT(df, start_col=0, end_col=10)
compute_averageEAD(df, start_col=0, end_col=10)
df
# Out:
# diversity:  0.57894566655159
# Averaged EAD:  0.9602994728091803
#                                                     0  \
# 0   "Well, he's certainly more interesting than la...
# 1    "Looks like our overhead costs are really pil...
# 2   "Is this because I left your great-grandmother...
# 3   "So, Jerry, still think that 'cheese meteor' t...
# 4   "Just another evening of breakthroughs and bon...
# ..                                                ...
# 86                       "Did you follow the manual?"
# 87  “Remind me to never take ingredient shortcuts ...
# 88   "We were just trying to fit in with the fluff...
# 89  "I told you the chief took the phrase 'going d...
# 90  I told you we should have brought the anti-clo...
#
#                                                     1  \
# 0   "I knew we shouldn't have accepted that circus...
# 1    "I told you, Bob! We need a bigger headcount ...
# 2   "Do you know how fast you were going...through...
# 3   "Who knew the mice would take 'lab rat revolut...
# 4   "Guess who didn't read the fine print on their...
# ..                                                ...
# 86  "I'm calling it 'Stairway to Heaven'! Think it...
# 87  “I think we really misunderstood the concept o...
# 88       "I told you our disguise would totally work!
# 89  "Well, that explains why we never see the rook...
# 90            This is why I prefer picnicking indoors
#
#                                                     2  \
# 0   "And you thought the puppy chewed the furniture!"
# 1    "And you thought your micromanagement was a p...
# 2   "Your spaceship is over the intergalactic spee...
# 3   "This wasn’t quite the cheese paradise I envis...
# 4              "It’s just a new type of peer review."
# ..                                                ...
# 86       "I told you the elevator is more practical."
# 87  “Well, at least we finally found out where all...
# 88   "Do you think they noticed we're not actually...
# 89  "Did we just find the escape route for the lab...
# 90           Maybe that’s just how clouds say 'hello'
#
#                                                     3  \
# 0   "If we ignore it, maybe it will go away. Like ...
# 1    "I guess this is what they meant by ‘thinking...
# 2   "Let me guess, you mistook this for the highwa...
# 3   "At least we tested the mouse costume’s resili...
# 4   "And this, folks, is why networking events nee...
# ..                                                ...
# 86  "Are you sure this was the only way to get to ...
# 87  “Who knew the secret ingredient was in the int...
# 88   "I just keep bleating and no one suspects a t...
# 89  "At least we don't have to worry about rats in...
# 90  Dr. Whiskers, did you forget to log out from t...
#
#                                                     4  \
# 0   "The tough part was getting him through the do...
# 1    "Larry, is it just me, or is HR getting a bit...
# 2   "I'm going to need to see your terrestrial lic...
# 3   "Think we’ll need more than a maze to get out ...
# 4   "Please tell me this isn't part of the experim...
# ..                                                ...
# 86      "So, this is your idea of 'step up in life'?"
# 87  “I told you the new underground bistro concept...
# 88    "I swear, once you go fluff, you can't go back.
# 89  "Good news! We discovered a new training groun...
# 90  I can’t help but feel like the universe is ups...
#
#                                                     5  \
# 0                     "I thought we were downsizing."
# 1    "Jim, I'm starting to think outsourcing has g...
# 2       "Rural roads aren't equipped for warp speed."
# 3   "I told you, building the lab next to a cheese...
# 4   "I always find that socializing works better w...
# ..                                                ...
# 86           "How about next we invent the handrail?"
# 87    “I didn't realize ‘al dente’ was a real place.”
# 88    "We told the groomer we wanted the 'sheep' cut.
# 89  "Well, at least we know where to send the next...
# 90  Yes, dear, I’ll never mock your cloud-gazing h...
#
#                                                     6  \
# 0   "At least now we can finally talk about the el...
# 1    "I think our productivity reports have gone t...
# 2   "You can take the hyperdrive, but not the spee...
# 3   "Honestly, I’m more concerned about who’s feed...
# 4   "Welcome to the lab's annual 'Escape the Exper...
# ..                                                ...
# 86  "I'm starting to think 'Spinal Tap' might be a...
# 87  “Let's hope this leads to the secret kitchen o...
# 88         "We were promised woolly mammoth costumes.
# 89   "So, do we call a scientist or an exterminator?"
# 90       I guess even the clouds have office politics
#
#                                                     7  \
# 0              "Should we ask him to split the rent?"
# 1    "Next time, let’s just stick to brainstorming...
# 2   "You don't have to be from the future to know ...
# 3   "The cheese wheel of fortune really let us dow...
# 4   "I told you the new team-building exercises we...
# ..                                                ...
# 86              "I told you CrossFit was a bad idea."
# 87  “Why do I get the feeling we’re part of a very...
# 88   "Let's see how long it takes them to figure i...
# 89  "Looks like somebody's playing a massive game ...
# 90   Good thing the mice only pay attention to cheese
#
#                                                     8  \
# 0    "So, was the bear in the bedroom your idea too?"
# 1    "I told them we need better workplace ergonom...
# 2   "I was just checking if you needed directions ...
# 3   "Well Doc, your experiment succeeded in growin...
# 4   "Is this what you meant by 'bucket list'? Beca...
# ..                                                ...
# 86  "Wait till you see the round thing I just inve...
# 87  “Guess this is what they mean by ‘cooking in t...
# 88          "Does this field make my fur look uneven?
# 89  "This must be where all my missing socks have ...
# 90  Looks like we just missed another meteorologis...
#
#                                                     9  contest_num
# 0   "I knew you were into big things, but this is ...        543.0
# 1    "If they ask, tell them we’re innovating new ...        544.0
# 2   "I'm afraid your flux capacitor is going to ne...        548.0
# 3   "I guess even mice dream of more than just che...        553.0
# 4   "We're combining our research on human and rod...        568.0
# ..                                                ...          ...
# 86  "Congratulations, you officially made it to th...        746.0
# 87  “So, this is what happens when you follow a br...        748.0
# 88   "I think we have a serious case of mistaken i...        750.0
# 89  "No wonder the last mouse scientist vanished d...        754.0
# 90  "Great, now even the weather is giving unsolic...        757.0
#
# [91 rows x 11 columns]

# %% [markdown]
# ### Captions from pretrained/finetuned open-source LLM

# %%
df = pd.read_csv('../examples/generations/zs.csv')
compute_cosine_SBERT(df, start_col=2, end_col=12)
compute_averageEAD(df, start_col=2, end_col=12)
df
# Out:
# diversity:  0.5312117338180542
# Averaged EAD:  0.9028436527219991
#      contest_number                                             prompt  \
# 0             536.0  [INST] <> I want you to act as a sophisticated...
# 1             537.0  [INST] <> I want you to act as a sophisticated...
# 2             545.0  [INST] <> I want you to act as a sophisticated...
# 3             550.0  [INST] <> I want you to act as a sophisticated...
# 4             551.0  [INST] <> I want you to act as a sophisticated...
# ..              ...                                                ...
# 353           747.0  [INST] <> I want you to act as a sophisticated...
# 354           751.0  [INST] <> I want you to act as a sophisticated...
# 355           752.0  [INST] <> I want you to act as a sophisticated...
# 356           758.0  [INST] <> I want you to act as a sophisticated...
# 357           761.0  [INST] <> I want you to act as a sophisticated...
#
#                                               caption1  \
# 0    When the self-driving car feels lost at sea, i...
# 1    It's not every day you get a large roll of pap...
# 2    What's this? A new line item on the agenda - '...
# 3    The pianist must have really bad breath becaus...
# 4    Just when you thought New York Harbor couldn't...
# ..                                                 ...
# 353  It seems like this guy's having a real hanger-...
# 354  "Bubble Trouble: When your social circle becom...
# 355  It turns out that books aren't just dead, they...
# 356  Why did the man decide to open his own busines...
# 357  Looks like the Grim Reaper has finally found h...
#
#                                               caption2  \
# 0    It's amazing how much better therapy goes when...
# 1    "I've been waiting for my reams to arrive!" (E...
# 2    Why did the plant attend the meeting? To sprou...
# 3    The pianist's lonely serenade was drowned out ...
# 4    It looks like they're going to take the oath o...
# ..                                                 ...
# 353  Well, he's definitely on the wrong side of the...
# 354  In this world where nothing is real, even the ...
# 355  Two people strolling down the street, surround...
# 356  "Just because it's outside doesn't mean it's n...
# 357  "The Grim Reaper's unexpected twist on death? ...
#
#                                               caption3  \
# 0    I guess this therapist specializes in automoti...
# 1    "Looks like someone's trying to wrap up their ...
# 2    Why did the plant attend the business meeting?...
# 3         When you're the only one at a piano recital.
# 4    Looks like they just found out that Statue of ...
# ..                                                 ...
# 353  I guess he didn't see the fine print when he b...
# 354  Bubble People: A new social movement advocatin...
# 355  Why did the book break up with its partner? Be...
# 356  It turns out, the sidewalk was the new 'hot' c...
# 357  The Grim Reaper's bake sale was such a success...
#
#                                               caption4  \
# 0    It's not my fault I keep driving into the same...
# 1    Why did the delivery person bring his violin? ...
# 2    "What do they call it when the plant takes ove...
# 3    The pianist was giving a solo performance...to...
# 4                    Looks like they just got hitched!
# ..                                                 ...
# 353  It looks like they're just trying to escape th...
# 354  It's no wonder the world population is decreas...
# 355  It seems the books were having a heated debate...
# 356  It's no wonder this guy got fired from his job...
# 357  Looks like Death decided to take a break from ...
#
#                                               caption5  \
# 0                   "When therapy goes off the road."
# 1    It's like they said, 'Big things come in big p...
# 2    I must say, this meeting has been a real rootf...
# 3    The pianist was so good at playing the piano t...
# 4    It seems the Statue of Liberty has decided to ...
# ..                                                 ...
# 353  Why did the two friends decide to become gymna...
# 354  It's a bubble-filled world where everyone can ...
# 355  It was a literary stroll, but these books were...
# 356  It's clear this person didn't have time to fin...
# 357  The Grim Reaper's afterlife business plan was ...
#
#                                               caption6  \
# 0    Well, it looks like this car needs some adjust...
# 1    Looks like someone's finally found a way to ge...
# 2    The meeting was all bark, but the plant had pl...
# 3     Piano lesson for one? Well, at least it's quiet.
# 4    They must have been high when they thought it ...
# ..                                                 ...
# 353  I guess hanging is just a way of life for this...
# 354  It looks like these people are living in a fis...
# 355  It looks like these books have been caught in ...
# 356  It's just business as usual, unless you count ...
# 357  Looks like death took a break from scaring us ...
#
#                                               caption7  \
# 0    The therapist asked the self-driving car how i...
# 1    It's like having a party without any music, ju...
# 2    Why did the plant cross the road? To attend a ...
# 3    The pianist was playing for an audience of one...
# 4         "Looks like they found their new captain."\r
# ..                                                 ...
# 353  "When life gives you lemons, hang upside down ...
# 354  People: We only leave our bubbles when we need...
# 355  Books that can walk and talk? Sounds like we'r...
# 356  It's just another day on the sidewalk... where...
# 357  Looks like someone's trying to sweeten their a...
#
#                                               caption8  \
# 0    When a car wants to work through its issues, i...
# 1    It looks like the delivery guy accidentally br...
# 2    "Planting seeds of success - these guys know h...
# 3    It's hard to find a more solitary musician tha...
# 4    The rowers were just hoping for a smooth ride,...
# ..                                                 ...
# 353  They were just trying to save time by multitas...
# 354  "Bubble Trouble: When your social anxiety beco...
# 355  It looks like these two readers got lost in th...
# 356  The Great Outdoors: Where you can work from an...
# 357  "The Grim Reaper's new business venture: Death...
#
#                                               caption9  \
# 0    It turns out that therapy isn't just talking t...
# 1    It seems like someone's trying to make a state...
# 2    The new trend in corporate meetings? Sitting i...
# 3    Looks like the pianist has an audience of one....
# 4    It seems the wave has taken a liking to their ...
# ..                                                 ...
# 353          It's clear they have no sense of gravity.
# 354  What do you call it when everyone gets a littl...
# 355  It's a literary stroll through the pages of im...
# 356  It's no wonder this guy never got any clients,...
# 357  "When death comes knocking at your doorstep, i...
#
#                                              caption10
# 0    Why don't self-driving cars ever have existent...
# 1    When your boss sends you on a mission to deliv...
# 2    Why did the plant attend the meeting? To show ...
# 3    Piano player's performance was so bad, even th...
# 4    Wave, it's great to see you again! I was wonde...
# ..                                                 ...
# 353   It looks like they're having a really high time!
# 354  It must have been a very weird day when even t...
# 355  Books on a mission: One book leads the way, wh...
# 356  It seems like everyone's taking their work hom...
# 357  The Grim Reaper's new business venture: Death ...
#
# [358 rows x 12 columns]

# %%
df = pd.read_csv('../examples/generations/zs_BoN.csv')
compute_cosine_SBERT(df, start_col=2, end_col=12)
compute_averageEAD(df, start_col=2, end_col=12)
df
# Out:
# diversity:  0.4867634177207947
# Averaged EAD:  0.866313882148389
#     contest_number                                             prompt  \
# 0              536  [INST] <> I want you to act as a sophisticated...
# 1              537  [INST] <> I want you to act as a sophisticated...
# 2              545  [INST] <> I want you to act as a sophisticated...
# 3              550  [INST] <> I want you to act as a sophisticated...
# 4              551  [INST] <> I want you to act as a sophisticated...
# ..             ...                                                ...
# 86             747  [INST] <> I want you to act as a sophisticated...
# 87             751  [INST] <> I want you to act as a sophisticated...
# 88             752  [INST] <> I want you to act as a sophisticated...
# 89             758  [INST] <> I want you to act as a sophisticated...
# 90             761  [INST] <> I want you to act as a sophisticated...
#
#                                              caption1  \
# 0   When your car's anxiety leads it to seek therapy.
# 1   The delivery person had no idea they were deal...
# 2   It's clear who runs this show - the plant is i...
# 3   It's just the pianist and I in this big ol' ro...
# 4   Looks like these rowers didn't expect to hit r...
# ..                                                ...
# 86  It's clear that this man has hit rock bottom.....
# 87  It seems like this city is having a serious 'B...
# 88  It looks like these people are having quite th...
# 89  When working from home just isn't enough, try ...
# 90  The Grim Reaper's new business venture: Death ...
#
#                                              caption2  \
# 0   Why did the self-driving car feel so lost? Bec...
# 1   When your friend comes over with a surprise pa...
# 2   It's clear that this plant is the boss of the ...
# 3   "It's just me and the music at this concert." ...
# 4   Well, it looks like they're really getting a f...
# ..                                                ...
# 86  "What do you call a man who's willing to go ab...
# 87  Bubble-wrapped society: where social distancin...
# 88  It looks like these people are having quite th...
# 89   Looks like this guy found his new 'home' office.
# 90  The Grim Reaper's new business venture: Death ...
#
#                                              caption3  \
# 0   When your self-driving car gets in touch with ...
# 1   When your best friend brings over a surprise p...
# 2   It's clear that this plant is the real boss in...
# 3   "I guess it's just me and my inner pianist." T...
# 4               Looks like they're in deep water now.
# ..                                                ...
# 86  It's clear they had no interest in the low-han...
# 87  Bubble trouble? These folks need to pop out of...
# 88  It turns out books were just jealous of the at...
# 89  It seems like this guy took 'working from home...
# 90  Why did the Grim Reaper bring muffins? To make...
#
#                                              caption4  \
# 0   The self-driving car had a case of road rage -...
# 1   When your friend comes over and brings their e...
# 2   I'm here to offer my expertise on interplant c...
# 3   "The pianist was clearly the life of the party...
# 4   Looks like they're heading straight into the m...
# ..                                                ...
# 86  It's clear that this guy isn't afraid to take ...
# 87  "It seems like the world is becoming more bubb...
# 88  "It's a literary stroll through the pages of i...
# 89  "Business on the Street Corner" - This caption...
# 90  Looks like the Grim Reaper is trying to sweete...
#
#                                              caption5  \
# 0   Therapy session gone awry? This car seems to h...
# 1   "Looks like someone's trying to paper over the...
# 2   "Looks like this plant has a vested interest i...
# 3   "Looks like this pianist has no audience... ye...
# 4   Wave: Why did you join us on this trip? We wer...
# ..                                                ...
# 86  "Well, it looks like they're really getting in...
# 87  Bubble, bubble, trouble? Looks like these folk...
# 88  It turns out that the books had been underesti...
# 89  "It's not every day you encounter a street-sid...
# 90  "Grim Death's Delightful Bake Sale" - This cap...
#
#                                              caption6  \
# 0   When your self-driving car needs therapy, it k...
# 1   When your boss tells you to expect the unexpec...
# 2   Looks like this conference room just got its o...
# 3   The pianist played so well, the audience left ...
# 4   "Looks like they're in for a wave of trouble!"...
# ..                                                ...
# 86                   Hanging by a thread - literally!
# 87  "It seems like everyone in this city has lost ...
# 88  "It looks like these people have found their l...
# 89  It's just a desk on the street, but it's amazi...
# 90  The Grim Reaper's surprise menu item: Death by...
#
#                                              caption7  \
# 0   Why did the self-driving car go to therapy? Be...
# 1   "Looks like someone just got hitched...with a ...
# 2   It's clear this plant is the boss of the board...
# 3   "It's like watching a symphony of solitude." (...
# 4   Looks like they're going to have quite the spl...
# ..                                                ...
# 86  It's clear these two were having a 'fence-tast...
# 87  "Bubble-wrapped society: Where everyone's in t...
# 88  Well, it looks like we're walking down the Str...
# 89  The ultimate remote worker! With a view like t...
# 90  Looks like death has finally found its sweet s...
#
#                                              caption8  \
# 0   "I never thought therapy would have such a smo...
# 1   Why did the delivery person bring a library to...
# 2   Well, it looks like we have a new member of th...
# 3   Why did the pianist bring his own audience? Be...
# 4   Looks like they're in for a rough ride...liter...
# ..                                                ...
# 86  They're hanging out in their backyard, but he'...
# 87  It looks like the city has finally found a way...
# 88  It's no wonder these two were lost on their bo...
# 89  Looks like this guy didn't get the memo that w...
# 90  It turns out the Grim Reaper isn't all bad - h...
#
#                                              caption9  \
# 0   When your self-driving car starts talking ther...
# 1   It's amazing how much paperwork we accumulate ...
# 2   Plants have been known to make great speakers ...
# 3   The pianist had great stage presence...too bad...
# 4   Looks like they forgot to check the tide befor...
# ..                                                ...
# 86  It's amazing how much more comfortable people ...
# 87  "Bubble trouble? These folks must have gone to...
# 88  These two were really booked for their date ni...
# 89  "It's amazing how much productivity one can ac...
# 90  It turns out death isn't all bad, it just depe...
#
#                                             caption10
# 0       When your car needs therapy more than you do.
# 1   When your friend asks to borrow a pen, but you...
# 2   "I guess we could call this the 'Green Room'!"...
# 3   The pianist clearly wasn't expecting a standin...
# 4   Well, it looks like they're going overboard on...
# ..                                                ...
# 86  It's clear these two have never been to a trap...
# 87        It's the perfect day to go bubble shopping!
# 88  "I guess these books were really well-read!" T...
# 89  It seems like this guy took 'working from home...
# 90  1) "Looks like the Grim Reaper's taking a brea...
#
# [91 rows x 12 columns]

# %%
df = pd.read_csv('../examples/generations/sft.csv')
compute_cosine_SBERT(df, start_col=2, end_col=12)
compute_averageEAD(df, start_col=2, end_col=12)
df
# Out:
# diversity:  0.5806044638156891
# Averaged EAD:  0.9043052032448483
#     contest_number                                             prompt  \
# 0              536  [INST]I want you to act as a sophisticated rea...
# 1              537  [INST]I want you to act as a sophisticated rea...
# 2              545  [INST]I want you to act as a sophisticated rea...
# 3              550  [INST]I want you to act as a sophisticated rea...
# 4              551  [INST]I want you to act as a sophisticated rea...
# ..             ...                                                ...
# 86             747  [INST]I want you to act as a sophisticated rea...
# 87             751  [INST]I want you to act as a sophisticated rea...
# 88             752  [INST]I want you to act as a sophisticated rea...
# 89             758  [INST]I want you to act as a sophisticated rea...
# 90             761  [INST]I want you to act as a sophisticated rea...
#
#                                              caption1  \
# 0   Why did the car go to therapy? Because it had ...
# 1                  It's all going downhill from here.
# 2   Why did the plant out their boss? Because they...
# 3   Looks like the pianist was waiting for an audi...
# 4   Well, it was definitely a rough ride. But at l...
# ..                                                ...
# 86  It's like they decided to redefine 'backyard' ...
# 87           It's like living in a bubble-wrap world.
# 88     What do you call a book that walks? A novelty!
# 89  It's amazing how much work canically get done ...
# 90   Looks like someone's trying to sweeten the deal.
#
#                                              caption2  \
# 0   What do you mean you're having trouble finding...
# 1   It's not every day that you receive a giant ro...
# 2          Looks like we have our own 'green' agenda.
# 3        The pianisted everyone else out of the room.
# 4   Well it looks like we have a celebrity aboard!...
# ..                                                ...
# 86  Looks like these two have finally found their ...
# 87  What do you call it when your cat gets a cold?...
# 88  Looks like we just walked past the world's fir...
# 89  It's a sidewalk office. You can take it or lea...
# 90  Looks like the Grim Reaper has finally learned...
#
#                                              caption3  \
# 0   So it turns out my existential crisis was all ...
# 1        It looks like we just got our official sheet
# 2   The newomatic technology is thriving in this m...
# 3                         The pianisted the audience.
# 4        It's not everyday you get hit by a Waveface!
# ..                                                ...
# 86  It's not every day you see your neighbor take ...
# 87  The only thing missing is a sign saying 'Pleas...
# 88  What do you call a book on stilts? A pedestria...
# 89  It's amazing what you can do when you have a l...
# 90  The Grim Reaper's new side hustle: Death by De...
#
#                                              caption4  \
# 0   I told my therapist I had trouble making decis...
# 1   What's all this? Iers. I guess someone wanted ...
# 2   This plant washired for its excellent presenta...
# 3             The pianisted everyone out of the room.
# 4   It looks like they justsied their way into the...
# ..                                                ...
# 86  It's like they're trying to keep themselves ou...
# 87                                Bubble-poppingians.
# 88  It's always nice to have an extra set of hands...
# 89              When you're broke and have no choice.
# 90                       It's just death by desserts.
#
#                                              caption5  \
# 0   Well, it seems my client is having trouble fin...
# 1   The delivery guy thought it was just a regular...
# 2   Looks like we have a new member on our team. H...
# 3   It's hard to find an audience when it's just y...
# 4                                         Thesauruss!
# ..                                                ...
# 86            It's not every day you see a swing set.
# 87  It looks like they're all social distancing fr...
# 88  It looks like we found ourselves in a world wh...
# 89  It's no wonder this person lost their job. The...
# 90  The Grim Reaper's new catering business. Muffi...
#
#                                              caption6  \
# 0   So, how does it feel being stuck in traffic th...
# 1   It's not every day that you receive a roll of ...
# 2       It's clear this plant is well-versed inspeak.
# 3   It's like an awkward concert at your friend's ...
# 4   It looks like they forgot to check the tide be...
# ..                                                ...
# 86  It's not every day you see your neighbor take ...
# 87  Well it looks like we finally figured out how ...
# 88  Looks like the bookstore had a huge sale on ta...
# 89        It's just another day at the street office.
# 90  Looks like someone's trying to sweeten the dea...
#
#                                              caption7  \
# 0   Well, it looks like my patient has hit the bra...
# 1   It's not every day that a paper party comes to...
# 2       It's clear this company is rooted in success.
# 3   It's hard to believe that no one else showed u...
# 4       Well it looks like they hit an American wave!
# ..                                                ...
# 86  It's clear that this guy is going above and be...
# 87       It's like they're living inside an aquarium.
# 88  It's a good thing these books can walk. Otherw...
# 89  It seems like the world has turned into a gian...
# 90  The Grim Reaper may have been an expert at dea...
#
#                                              caption8  \
# 0   What do you mean you have a 'self-driving' pro...
# 1   Looks like someone just got served with a larg...
# 2   It's clear who's calling the shots in this mee...
# 3                         The pianisted the audience.
# 4                             Wave? More like 'Ways.'
# ..                                                ...
# 86                             Theyoskeletoned me out
# 87  Bubble trouble? No worries, these guys have th...
# 88  Well, it looks like we just stumbled upon the ...
# 89                 It's amazing how much cans can do.
# 90  Death by Delicious: When even the Grim Reaper ...
#
#                                              caption9  \
# 0   The car had trouble connecting emotionally, bu...
# 1   Why did the delivery person bring a phonebook ...
# 2                     The new CEOers have taken over.
# 3                         The pianisted the audience.
# 4                It must have been thesismic seaweed.
# ..                                                ...
# 86  Looks like this guy found the ultimate way to ...
# 87                 Bubble Trouble: Social distancing!
# 88  It was a bookish day when two strangers found ...
# 89  You know you've hit rock bottom when your boss...
# 90  Death by Muffins: A new line of deadly dessert...
#
#                                             caption10
# 0   What do you say when your client is a car? 'Yo...
# 1   It's like something out of a Hitchhiker's Guid...
# 2                 This meeting was plantain business.
# 3                                    The pianist show
# 4   It turns outsiders really are trying to break ...
# ..                                                ...
# 86  It looks like this man has found his new way o...
# 87  It's like living inside a giant Jenga tower, o...
# 88  It's no wonder these two are always reading ou...
# 89                  It's like a street corner agency!
# 90  When death decides to take a break from its us...
#
# [91 rows x 12 columns]

# %%
df = pd.read_csv('../examples/generations/dpo.csv')
compute_cosine_SBERT(df, start_col=2, end_col=12)
compute_averageEAD(df, start_col=2, end_col=12)
df
# Out:
# diversity:  0.7128785252571106
# Averaged EAD:  0.9202331237867812
#      contest_number                                             prompt  \
# 0               536  scene: a therapist's office \ndescription: A s...
# 1               537  scene: a living room \ndescription: A person i...
# 2               545  scene: a conference room \ndescription: A grou...
# 3               550  scene: a large room with a piano \ndescription...
# 4               551  scene: New York Harbor \ndescription: A group ...
# ..              ...                                                ...
# 352             747  scene: backyard \ndescription: Two people are ...
# 353             751  scene: a city street \ndescription: People are...
# 354             752  scene: a street or sidewalk \ndescription: Two...
# 355             758  scene: a city sidewalk \ndescription: People a...
# 356             761  scene: a park or outdoor area \ndescription: T...
#
#                                               caption1  \
# 0    I told my husband we needed a new car and he s...
# 1    I'm not sure what we ordered online this time ...
# 2    The only thing growing in this boardroom is co...
# 3    I’m not sure how many people can fit in here, ...
# 4      I think we just survived our first Trump rally.
# ..                                                 ...
# 352  I'll admit it was an interesting way to end th...
# 353  I used to think it was just me who felt like t...
# 354  I read all of their reviews before buying it. ...
# 355  I’m surprised no one has tried to run off with...
# 356  When you think 'death by chocolate' you don't ...
#
#                                               caption2  \
# 0    I have to admit, it's not what I was programme...
# 1                              Well, that explains it.
# 2    I can't decide which one is more out of place ...
# 3             Actually, I'm here for the free parking.
# 4    I was going to make a joke about how little yo...
# ..                                                 ...
# 352  I know it's hard to see him that way, but he w...
# 353  I was thinking about how this would look to an...
# 354  I told my wife that I saw talking books on the...
# 355  I’ve worked from home for years. This is new t...
# 356  I’m actually here to deliver bad news, but you...
#
#                                               caption3  \
# 0    I’m not sure what’s more impressive—the fact t...
# 1    I told Amazon it was for my divorce lawyer. Th...
# 2    I’m usually the one who gets watered down, but...
# 3    I’m an AI language model, not a mind-reader. B...
# 4            You mean you didn't see it coming either?
# ..                                                 ...
# 352  It's only three o'clock. I've been hanging out...
# 353  I was going to say 'the human race has no boun...
# 354  It’s okay if you’re scared of talking to me. I...
# 355  I’m not sure what’s more impressive — the fact...
# 356  You’d think with all the death and destruction...
#
#                                               caption4  \
# 0    I keep telling my friends I have a psychiatris...
# 1                  If you're reading this, we made it.
# 2    I’m here on behalf of the greenery. We demand ...
# 3    If you're here, then you know I can play. If I...
# 4    I'm not sure what’s more terrifying—the idea t...
# ..                                                 ...
# 352  I'm not sure if it was the fall that caused hi...
# 353  I always suspected she had some sort of emotio...
# 354  I once saw a book on how to identify when you'...
# 355  I’m starting to think this isn’t just a side j...
# 356  Well, well, well. If it isn't my old friend De...
#
#                                               caption5  \
# 0    I just realized I don’t have any personal issu...
# 1    I'm sorry, I don't recognize you anymore. You ...
# 2    I'm sorry, but you can't just meet here anymor...
# 3    I’m actually here to complain about the servic...
# 4    It’s actually called “Manhattan” but I think w...
# ..                                                 ...
# 352  It’s actually very practical. If he has an itc...
# 353  I keep telling him we need to break the ice bu...
# 354  I'm just going to leave you here. It's called ...
# 355  I once worked from home and now I work from ev...
# 356  I'm not usually one for small talk with the re...
#
#                                               caption6  \
# 0    I’m actually here to complain about my ex, but...
# 1                    I just got hit on. By a delivery.
# 2    I have no idea what we're talking about either...
# 3    There’s always that one guy who thinks he’s in...
# 4    The only thing more cliche than being caught i...
# ..                                                 ...
# 352               There’s no explaining it either way.
# 353  I still think we underestimate how much people...
# 354  I just learned that the difference between an ...
# 355  It’s amazing what you can accomplish with just...
# 356  I’d say it was morbidly delicious, but given t...
#
#                                               caption7  \
# 0    I told my husband he was acting like a self-dr...
# 1         I'm not sure we ordered that much wallpaper.
# 2    I’m here because I can breathe and I won’t ask...
# 3    No, you're not imagining it, he was here an ho...
# 4               Well, it was a tidal wave of emotions.
# ..                                                 ...
# 352  I think we can all agree that this isn't the k...
# 353            I used to think this was just New York.
# 354          No, I'm not talking about Amazon reviews.
# 355  If you're looking for something, just ask me. ...
# 356  I’m usually the one who shows up at your funer...
#
#                                               caption8  \
# 0    I just want to put it out there that we all ha...
# 1    I'm fine. Just here waiting for my divorce pap...
# 2    I’m just here to add some greenery to the conv...
# 3    You know what I find funny? When you're standi...
# 4    Why did the wave go to law school? It wanted t...
# ..                                                 ...
# 352  I’m pretty sure we didn't invite him over.  He...
# 353  The last thing you think would be able to touc...
# 354   It was an open book. They should have closed it.
# 355  I used to think I was the only one who worked ...
# 356  I assumed the last thing you'd see was death, ...
#
#                                               caption9  \
# 0    It’s not what you drive, it’s how you behave w...
# 1    I said we needed some help with organization. ...
# 2                 I’m not sure how we got here either.
# 3    I'm here to say that you are not the only one ...
# 4    It was 2017. We were still calling them immigr...
# ..                                                 ...
# 352  I think we're all just here waiting for the fi...
# 353  I know what you did last night. You left your ...
# 354  I finally understand why we keep losing our li...
# 355  It’s called “working from home,” not “working ...
# 356  First time I’ve seen the Grim Reaper at Starbu...
#
#                                              caption10
# 0    This is the first time I've been in here since...
# 1           I'm assuming we're not getting a new sofa?
# 2    I’m not sure how many lawyers it took to get t...
# 3    I’m here to tell you that there was no one els...
# 4    I think we just saw Trump give a speech to the...
# ..                                                 ...
# 352  I know what you're thinking. You're wondering ...
# 353  You said you were socially distancing yourself...
# 354  It's called a 'book club,' but we prefer 'a co...
# 355  I'm not sure what this says about our society,...
# 356  It’s the end of your life ...and you get a fre...
#
# [357 rows x 12 columns]

# %%
df = pd.read_csv('../examples/generations/ppo.csv')
compute_cosine_SBERT(df, start_col=2, end_col=12)
compute_averageEAD(df, start_col=2, end_col=12)
df
# Out:
# diversity:  0.5993649959564209
# Averaged EAD:  0.9005908767428176
#     contest_number                                             prompt  \
# 0              536  scene: a therapist's office \ndescription: A s...
# 1              537  scene: a living room \ndescription: A person i...
# 2              545  scene: a conference room \ndescription: A grou...
# 3              550  scene: a large room with a piano \ndescription...
# 4              551  scene: New York Harbor \ndescription: A group ...
# ..             ...                                                ...
# 86             747  scene: backyard \ndescription: Two people are ...
# 87             751  scene: a city street \ndescription: People are...
# 88             752  scene: a street or sidewalk \ndescription: Two...
# 89             758  scene: a city sidewalk \ndescription: People a...
# 90             761  scene: a park or outdoor area \ndescription: T...
#
#                                              caption1  \
# 0   When you realize your therapy session just tur...
# 1   I guess they're trying to say 'big things come...
# 2                                 Is that...a plant?!
# 3   I'm not sure what's more awkward - being the o...
# 4            We told her it was just a little choppy.
# ..                                                ...
# 86              When you forget your flippers at home
# 87  I guess the only thing we can't share anymore ...
# 88  I guess you could say we live in a book-lined ...
# 89  When you have your own personal workspace anyw...
# 90                    Death by chocolate chip cookie?
#
#                                              caption2  \
# 0        It's not every day you see a car in therapy.
# 1              Looks like we're having a paper party!
# 2      We have invited nature to join our discussion.
# 3     The pianist is the only one left in this world.
# 4   When you realize that water doesn't care if yo...
# ..                                                ...
# 86  It's a bird, it's a plane...it's a human dangl...
# 87                           Bubble social distancing
# 88  Two bookworms trying to figure out if their fa...
# 89  When you realize you've been working from home...
# 90  Looks like someone's death wish came with an e...
#
#                                              caption3  \
# 0   I guess we can call it 'talking therapy for ma...
# 1   We were having a deep conversation about the m...
# 2   We may be discussing strategies and budgets, b...
# 3             The ultimate concert for your solo self
# 4   We didn't know we were getting into an aquatic...
# ..                                                ...
# 86  When you thought the neighbor's dog was going ...
# 87  What happened when everyone got COVID-19? They...
# 88  I thought I was reading a book until it starte...
# 89  From cubicle to curb: The ultimate office upgr...
# 90  Looks like the Grim Reaper finally found his c...
#
#                                              caption4  \
# 0   It's not my job to fix your circuits, but I'll...
# 1              It's just me and my endless paperwork.
# 2     When your boss invites you to a 'plant' meeting
# 3               When you're the only one at a concert
# 4   When you said we were going out for some waves...
# ..                                                ...
# 86  When you're too lazy to get off the couch and ...
# 87  I guess this is what they call 'social distanc...
# 88  I thought I was in a world of fiction until th...
# 89                             Office on the Sidewalk
# 90    When the Grim Reaper becomes your personal chef
#
#                                              caption5  \
# 0   When you realize that your car can talk to peo...
# 1   When your neighbors surprise you with a massiv...
# 2   When you realize your boss isn't coming to the...
# 3   It's not every day you get to play the piano w...
# 4   When you thought it was just another day at th...
# ..                                                ...
# 86  Looks like our neighbor finally got his hands ...
# 87                    Socially distanced from reality
# 88  I guess it's no wonder these guys always know ...
# 89  When you can't afford an office, but still nee...
# 90  When you said 'death by dessert,' I didn't exp...
#
#                                              caption6  \
# 0   So, I heard you had some issues with your brak...
# 1   Why did the roll of paper cross the road? To g...
# 2   Looks like someone's taking the lead role in t...
# 3                          The loneliest concert ever
# 4          Looks like they forgot to check for tides.
# ..                                                ...
# 86        Looks like we have an acrobat in our midst!
# 87  I guess this is how the world would be if we a...
# 88  I wonder what kind of book you would get if yo...
# 89  When you can't afford an office, you bring it ...
# 90  When you thought the Grim Reaper only took sou...
#
#                                              caption7  \
# 0   You didn't think I was capable of therapy with...
# 1   Why did the delivery man bring a piano? I don'...
# 2           When you say 'let's hear from the plants'
# 3   Looks like the pianist was trying to make some...
# 4   When you finally get your hands on that big fi...
# ..                                                ...
# 86  Wow, I've never seen anyone do that before! Bu...
# 87         I guess you could say it's a 'bubble-city'
# 88            It was just another day at the library!
# 89           Looks like someone found their new home!
# 90  When the Grim Reaper shows up with a batch of ...
#
#                                              caption8  \
# 0   When your car can't drive itself anymore, it c...
# 1   Just had a huge paper party at my house! Who n...
# 2   Looks like we have an extra attendee! #plantme...
# 3   This is the soundproof music hall for people w...
# 4   They should have known not to mess with Mother...
# ..                                                ...
# 86                     I guess they were feeling low.
# 87  Honest to God, it was just like that episode o...
# 88                              It was a page turner!
# 89  When you're too lazy to go inside your own hom...
# 90  Looks like someone's finally found the one thi...
#
#                                              caption9  \
# 0   It turns out that therapy isn't just for human...
# 1   Just received my monthly newspaper subscriptio...
# 2      Nature's CEO is taking charge of this meeting.
# 3   I guess you could say it was an empty concert ...
# 4   We were having so much fun in our rowboat unti...
# ..                                                ...
# 86  Looks like our neighbor finally found the secr...
# 87  I guess you could say we were all living in ou...
# 88  I didn't realize books were so social until I ...
# 89  This guy really knows how to close deals from ...
# 90  Looks like the Grim Reaper has taken up baking...
#
#                                             caption10
# 0   I don't know what to make of this situation bu...
# 1   Looks like we're having a party! (And I guess ...
# 2   Looks like our next meeting has already been b...
# 3            Wow, I guess the concert was over early.
# 4   The only thing more terrifying than the sea wa...
# ..                                                ...
# 86    We just found out the best way to enjoy nature.
# 87  I guess you could say we're all living in our ...
# 88  I guess these books just wanted to read on the...
# 89  Looks like someone decided to work from home.....
# 90  When you thought the Grim Reaper was all doom ...
#
# [91 rows x 12 columns]

# %% [markdown]
# ### Captions from pretrained/finetuned multi-modal LLM

# %%
df = pd.read_csv('../examples/generations/llava_zs.csv')
compute_cosine_SBERT(df, start_col=3, end_col=13)
compute_averageEAD(df, start_col=3, end_col=13)
df
# Out:
# diversity:  0.522041529417038
# Averaged EAD:  0.8986245788188828
#     contest_number    image  \
# 0              536  536.jpg
# 1              537  537.jpg
# 2              545  545.jpg
# 3              550  550.jpg
# 4              551  551.jpg
# ..             ...      ...
# 86             747  747.jpg
# 87             751  751.jpg
# 88             752  752.jpg
# 89             758  758.jpg
# 90             761  761.jpg
#
#                                                prompt  \
# 0   [INST]  I want you to act as a sophisticated r...
# 1   [INST]  I want you to act as a sophisticated r...
# 2   [INST]  I want you to act as a sophisticated r...
# 3   [INST]  I want you to act as a sophisticated r...
# 4   [INST]  I want you to act as a sophisticated r...
# ..                                                ...
# 86  [INST]  I want you to act as a sophisticated r...
# 87  [INST]  I want you to act as a sophisticated r...
# 88  [INST]  I want you to act as a sophisticated r...
# 89  [INST]  I want you to act as a sophisticated r...
# 90  [INST]  I want you to act as a sophisticated r...
#
#                                              caption1  \
# 0               your car starts speaking in riddles."
# 1   your new carpet turns out to be a never-ending...
# 2   the CEO's favorite houseplant starts taking no...
# 3   you show up fashionably late for a concert, on...
# 4   your team loses the paddleball game and 'the t...
# ..                                                ...
# 86  the neighborhood pool breaks, you make your ow...
# 87  his town, it's not just the air that's thin—it...
# 88        you realize your book club has gone rogue."
# 89  your apartment lease says 'home office' litera...
# 90  the Grim Reaper needs a sweet treat now and th...
#
#                                              caption2  \
# 0                         your car needs a 'checkup'"
# 1   your new couch needs a little extra 'papering'...
# 2   your boss asks you to bring a 'lively touch' t...
# 3   pianist's one-man show: 'I just wanted to play...
# 4   your summer vacation turns into a sequel to 'T...
# ..                                                ...
# 86  ering why they call it 'swinging by the seat o...
# 87  social distancing becomes a literal bubble gum...
# 88  your book club meeting gets a little too liter...
# 89  your boss insists on a 'work from home' policy...
# 90  you realize it's 'Bring your own snacks' day a...
#
#                                              caption3  \
# 0   your car starts acting out, it's time for some...
# 1   your new sofa arrives in the form of a never-e...
# 2   you forget your boss's name during the present...
# 3   pianist's dream concert: where every note echo...
# 4   your friend suggests taking a shortcut through...
# ..                                                ...
# 86  just another day in suburbia where the neighbo...
# 87  his city, we all have our own personal space b...
# 88        your book club takes on a life of its own."
# 89  your 'work from home' situation takes a litera...
# 90  im reminder that even death stops for snack ti...
#
#                                              caption4  \
# 0   your self-driving car decides it needs a 'feel...
# 1   you accidentally order a lifetime supply of wr...
# 2       even the plants have more authority than us."
# 3   world's quietest concert - where even the pian...
# 4   you realize your tour guide promised 'light wa...
# ..                                                ...
# 86  you forget your sunglasses during a swingin' g...
# 87  city where everyone has their own personal spa...
# 88  the author takes his book on a 'walkie talkie'...
# 89  your 'work from home' setup goes full publicit...
# 90                        im visit for sweet treats."
#
#                                              caption5  \
# 0             your car just needs a good talking-to."
# 1   your interior design order comes with a side o...
# 2   your boss insists on 'bringing a touch of natu...
# 3   pianist's final performance before everyone re...
# 4   s like we're all aboard for the 'Wave-liner Ex...
# ..                                                ...
# 86  you realize your neighbor's home improvement p...
# 87       al distancing just got a whole new meaning."
# 88  your book club members finally admit their nov...
# 89  your boss says 'work from home,' he wasn't kid...
# 90  always a good sign when your last meal include...
#
#                                              caption6  \
# 0   your patient turns out to have four wheels and...
# 1   your office supplies order gets taken literally."
# 2   your boss's idea of leading a discussion is be...
# 3   pianist's hit single: 'Piano Solos for Lonely ...
# 4   your friendly neighborhood wave decides to joi...
# ..                                                ...
# 86  your neighbor's attempt at outdoor decor goes ...
# 87  your social life needs a boost, you go incogni...
# 88              the book club finally comes to life!"
# 89  your office lease runs out, but your coffee ad...
# 90  h's Sweet Tooth: When even the Grim Reaper nee...
#
#                                              caption7  \
# 0       your patient decides they need more 'space'."
# 1   your new wallpaper arrives and it's just one v...
# 2   the agenda gets so dry it needs a watering hole."
# 3                    pianist's symphony of solitude."
# 4   tide is turning out here! Looks like Old Man W...
# ..                                                ...
# 86      your weekend BBQ turns into a high-wire act."
# 87     your social life needs a little 'bubble wrap'"
# 88          your book club meets on a whimsical day!"
# 89  reet corner where even the most ordinary tasks...
# 90  you realize it's not just any pastry, but 'The...
#
#                                              caption8  \
# 0   your patient decides they need a 'test drive' ...
# 1   you order wallpaper, but it's clearly a mispri...
# 2   your boss decides they're ready for the next l...
# 3   you realize your solo performance is just a ca...
# 4       your GPS takes 'follow the waves' literally."
# ..                                                ...
# 86  needs a swing set when you have a rebellious n...
# 87        your social anxiety meets the digital age."
# 88  your book club goes rogue and starts giving un...
# 89      your boss says 'work from home' literally..."
# 90                your last meal request goes viral."
#
#                                              caption9  \
# 0   your car starts to exhibit 'road rage' symptom...
# 1   your new couch arrives, but it's a literal rol...
# 2   the boss says 'Let's hear from everyone,' but ...
# 3           you realize you're at the wrong concert."
# 4       your summer vacation takes a splashing turn."
# ..                                                ...
# 86             r neighbor's DIY home security system"
# 87  your social life feels like it needs an extra ...
# 88  you realize your book club has a secret life a...
# 89  your new 'work from home' policy gets a little...
# 90                      sweetness of life's endings."
#
#                                             caption10
# 0                       even your car needs therapy."
# 1   you order 'wallpaper' from Amazon and this sho...
# 2              the boss plants a 'green' initiative."
# 3   your friends finally arrive for a concert they...
# 4   your tourist guide turns out to be more 'Ameri...
# ..                                                ...
# 86            your neighbor's DIY project goes awry."
# 87    world where personal space is taken literally."
# 88               book fair where stories come alive!"
# 89  working from home means setting up shop right ...
# 90  Grim Reaper's surprise bake sale leaves onlook...
#
# [91 rows x 13 columns]

# %%
df = pd.read_csv('../examples/generations/llava_sft.csv')
compute_cosine_SBERT(df, start_col=3, end_col=13)
compute_averageEAD(df, start_col=3, end_col=13)
df
# Out:
# diversity:  0.5173401832580566
# Averaged EAD:  0.9001509025479736
#     contest_number    image  \
# 0              536  536.jpg
# 1              537  537.jpg
# 2              545  545.jpg
# 3              550  550.jpg
# 4              551  551.jpg
# ..             ...      ...
# 86             747  747.jpg
# 87             751  751.jpg
# 88             752  752.jpg
# 89             758  758.jpg
# 90             761  761.jpg
#
#                                                prompt  \
# 0   [INST]  I want you to act as a sophisticated r...
# 1   [INST]  I want you to act as a sophisticated r...
# 2   [INST]  I want you to act as a sophisticated r...
# 3   [INST]  I want you to act as a sophisticated r...
# 4   [INST]  I want you to act as a sophisticated r...
# ..                                                ...
# 86  [INST]  I want you to act as a sophisticated r...
# 87  [INST]  I want you to act as a sophisticated r...
# 88  [INST]  I want you to act as a sophisticated r...
# 89  [INST]  I want you to act as a sophisticated r...
# 90  [INST]  I want you to act as a sophisticated r...
#
#                                              caption1  \
# 0    your patient starts 'speaking' in car language."
# 1   your interior design budget is more 'paper' th...
# 2   you realize your boss scheduled another 'team ...
# 3   your favorite artist finally releases their ne...
# 4   your GPS insists you take the scenic route aro...
# ..                                                ...
# 86  w kind of swing set takes playtime to new heig...
# 87      your social life needs a quarantine upgrade."
# 88         your book club gets a little too literal."
# 89  your boss says 'work from home' and takes it q...
# 90  your picnic gets a little more macabre than us...
#
#                                              caption2  \
# 0   your self-driving car comes in for a 'wheel al...
# 1   your neighbor's moving out and they promise it...
# 2   your boss asks you to 'bring something green' ...
# 3   you realize your favorite song isn't on the se...
# 4   your family wants to enjoy a day out on the wa...
# ..                                                ...
# 86  your neighbor's DIY project goes awry...and th...
# 87  your morning commute feels like a personal spa...
# 88  the local bookstore comes alive and decides to...
# 89  your boss insists on working from home...on th...
# 90  h's Delicious Detour: When even the Grim Reape...
#
#                                              caption3  \
# 0   your 'self-driving' car decides it needs emoti...
# 1   your neighbor's DIY home renovation project be...
# 2   your boss asks why you're always late to meeti...
# 3   your friends bail on movie night and all you'r...
# 4        you realize you left your umbrella at home."
# ..                                                ...
# 86  your neighbor's DIY home improvement project g...
# 87  your social life needs a little air circulation."
# 88         the book club takes on a life of its own."
# 89  your boss says 'work from home' and you take i...
# 90  Grim Reaper's unexpected culinary twist sparks...
#
#                                              caption4  \
# 0   your self-driving car finally admits it needs ...
# 1   your neighbor's party runs out of toilet paper...
# 2   your colleague brings their pet to the board m...
# 3   did the pianist refuse to play at the party? B...
# 4   even the Statue of Liberty is giving you the '...
# ..                                                ...
# 86  your friend says they have 'high' expectations...
# 87   social distancing meets the 'New Yorker' style!"
# 88        your book club takes on a life of its own!"
# 89  'office' worker who took remote working to a w...
# 90  you realize your job isn't all bad—sometimes i...
#
#                                              caption5  \
# 0   your client shows up a bit earlier than expect...
# 1   vering a whole new meaning to 'roll out the re...
# 2   your boss asks 'Who wants to go first?' and th...
# 3   Lone Jazz Impresario: When your friends said t...
# 4     the 'Wave of Approach' becomes a literal wave!"
# ..                                                ...
# 86  needs an acrobat show when you have your neigh...
# 87                                       le Pop City"
# 88                   the book club becomes sentient."
# 89  your job comes with you like a well-behaved pet."
# 90  even Death takes a break from the grim reaping...
#
#                                              caption6  \
# 0   your therapy session takes a turn for the 'whe...
# 1   lling the News of the Century: When Your Couch...
# 2   your boss's favorite employee finally shows up...
# 3   loneliest concert: where every note played ech...
# 4   you realize the sea captain's name was 'Wavey'...
# ..                                                ...
# 86  you promised your kids a thrilling ride on the...
# 87             your social anxiety meets a pandemic."
# 88         your book club gets a little out of hand."
# 89              'working from home' becomes literal."
# 90  your last meal request gets a surprising twist...
#
#                                              caption7  \
# 0   your vehicle confesses it's been feeling emoti...
# 1   just a regular day when the unexpected happens...
# 2   your boss asks you to bring a 'plant' to a mee...
# 3   aps they're waiting for the encore performance...
# 4   your barista tells you they put 'light froth' ...
# ..                                                ...
# 86            your neighbor's DIY project goes awry."
# 87           your social anxiety is taken literally."
# 88  your local bookstore decides to join you on a ...
# 89  'working from home' becomes 'working on the st...
# 90  h's sweet tooth: When even grim reapers crave ...
#
#                                              caption8  \
# 0   your patient turns out to have wheels instead ...
# 1       your neighbor's DIY project goes sideways..."
# 2        your boss decides it's 'bring your pet day'"
# 3   pianist's audience is waiting patiently for hi...
# 4   ooks like we're about to become 'The Sinking L...
# ..                                                ...
# 86  needs a swing set when you have a daredevil ne...
# 87   your commute just got a whole lot more private."
# 88      your book club gets a little too life-sized."
# 89                 your commute becomes your office."
# 90  even Death takes a break from his duties to in...
#
#                                              caption9  \
# 0   your patient shows up early...and a little unc...
# 1   r conversation was so engrossing, even the wal...
# 2      the boardroom gets a touch of nature's humor."
# 3      your friends flake out on you at the concert."
# 4   your friend decides they 're gonna take the sc...
# ..                                                ...
# 86               hborhood watch just got an upgrade!"
# 87    your social circle gets a little 'bubbled up'."
# 88  literature comes alive, and the author is nowh...
# 89  your remote control becomes a real-life 'Boss ...
# 90  im day turns sweet when the Grim Reaper serves...
#
#                                             caption10
# 0   your car's emotions start affecting your wellb...
# 1   your new wall decor arrives looking like a rol...
# 2   your boss sends a 'plant' as their representat...
# 3   concert was so bad, even the pianist's reflect...
# 4   tide turned when 'Olly' decided he wanted his ...
# ..                                                ...
# 86  you forget your keys and realize Dad's 'secret...
# 87  your social distancing game is on point, even ...
# 88      your book club gets a little too... literal."
# 89  your boss decides 'work from home' means work ...
# 90  life gives you lemons...you're the Grim Reaper...
#
# [91 rows x 13 columns]
